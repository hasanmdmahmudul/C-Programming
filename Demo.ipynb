# %% [markdown]
# <a href="https://colab.research.google.com/github/hasanmdmahmudul/C-Programming/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Reading, showing and writing images
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# run this cell to see the helptext
cv2.imread?

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img=cv2.imread("/content/gdrive/MyDrive/COMP9517_T2_2022/Demo_2022/hasan.PNG")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=652x742 at 0x7F9A0A981250>

# %%
img.shape
# Out:
# (742, 652, 3)

# %%
cv2.imwrite("/content/gdrive/MyDrive/COMP9517_T2_2022/Demo_2022/hasan3.jpg",img)
# Out:
# True

# %%
from google.colab import files
#uploaded = files.upload()
files.download('/content/gdrive/MyDrive/COMP9517_T2_2022/Demo_2022/hasan3.jpg')
